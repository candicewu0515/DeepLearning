# %%
import numpy as np
import pandas as pd
import os
import seqlogo
import logomaker
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from PIL import Image
import io

# %% [markdown]
# 产生seqlogo的图

# %%
def parse_meme_file(file_path):
    motifs = []
    current_motif = []
    reading_motif = False
    
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('MOTIF'):
                if current_motif:
                    motifs.append(pd.DataFrame(current_motif, columns=['A', 'C', 'G', 'T']))
                    current_motif = []
                reading_motif = True
            elif line.startswith('letter-probability matrix'):
                reading_motif = True
            elif reading_motif and line.strip() and not line.startswith('---'):
                values = [float(num) for num in line.split()]
                current_motif.append(values)
    
    # Add the last motif
    if current_motif:
        motifs.append(pd.DataFrame(current_motif, columns=['A', 'C', 'G', 'T']))
    
    return motifs

# %% [markdown]
# file_path = 'meme_file_multitask_TRASH_3L.txt'
# motifs = parse_meme_file(file_path)
#
# pdf_dir = 'tfmodisco_seqlogo_3L'
# os.makedirs(pdf_dir, exist_ok=True)
#
# for i, motif_df in enumerate(motifs):
#     if not motif_df.empty:
#         ppm = seqlogo.Ppm(motif_df.T)
#         png_path = os.path.join(pdf_dir, f'motif_{i+1}.png')
#         seqlogo.seqlogo(ppm, ic_scale=True, format='png', size='medium', filename=png_path)
#     else:
#         print(f"Motif {i+1} is empty.")

# %% [markdown]
# 输出number of seqlets

# %%
import h5py
import numpy as np

hdf5_results = h5py.File("/rugpfs/fs0/zhao_lab/scratch/xwu05/detect_peaks_scripts/run_model/multitask_results_X.hdf5","r")


metacluster_names = [x.decode("utf-8") for x in list(hdf5_results["metaclustering_results"]["all_metacluster_names"][:])]

patterns_list = []

# 遍历所有的metaclusters和它们的patterns
for metacluster_name in metacluster_names:
    metacluster_grp = hdf5_results["metacluster_idx_to_submetacluster_results"][metacluster_name]
    all_pattern_names = [x.decode("utf-8") for x in list(metacluster_grp["seqlets_to_patterns_result"]["patterns"]["all_pattern_names"][:])]

    for pattern_name in all_pattern_names:
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        num_seqlets = len(pattern["seqlets_and_alnmts"]["seqlets"])
        
        # 将模式和seqlets数量添加到列表中
        patterns_list.append((metacluster_name + pattern_name, num_seqlets))


for item in patterns_list:
    print(f"Pattern: {item[0]}, Total seqlets: {item[1]}")

with open("patterns_seqlets_list_X.txt", "w") as f:
    for item in patterns_list:
        f.write(f"Pattern: {item[0]}, Total seqlets: {item[1]}\n")
# Out:
# Pattern: metacluster_0pattern_0, Total seqlets: 2426
# Pattern: metacluster_0pattern_1, Total seqlets: 1913
# Pattern: metacluster_0pattern_2, Total seqlets: 1711
# Pattern: metacluster_0pattern_3, Total seqlets: 928
# Pattern: metacluster_0pattern_4, Total seqlets: 642
# Pattern: metacluster_0pattern_5, Total seqlets: 633
# Pattern: metacluster_0pattern_6, Total seqlets: 612
# Pattern: metacluster_0pattern_7, Total seqlets: 602
# Pattern: metacluster_0pattern_8, Total seqlets: 539
# Pattern: metacluster_0pattern_9, Total seqlets: 533
# Pattern: metacluster_0pattern_10, Total seqlets: 532
# Pattern: metacluster_0pattern_11, Total seqlets: 513
# Pattern: metacluster_0pattern_12, Total seqlets: 464
# Pattern: metacluster_0pattern_13, Total seqlets: 450
# Pattern: metacluster_0pattern_14, Total seqlets: 420
# Pattern: metacluster_0pattern_15, Total seqlets: 413
# Pattern: metacluster_0pattern_16, Total seqlets: 413
# Pattern: metacluster_0pattern_17, Total seqlets: 387
# Pattern: metacluster_0pattern_18, Total seqlets: 364
# Pattern: metacluster_0pattern_19, Total seqlets: 357
# Pattern: metacluster_0pattern_20, Total seqlets: 351
# Pattern: metacluster_0pattern_21, Total seqlets: 321
# Pattern: metacluster_0pattern_22, Total seqlets: 315
# Pattern: metacluster_0pattern_23, Total seqlets: 299
# Pattern: metacluster_0pattern_24, Total seqlets: 263
# Pattern: metacluster_0pattern_25, Total seqlets: 251
# Pattern: metacluster_0pattern_26, Total seqlets: 236
# Pattern: metacluster_0pattern_27, Total seqlets: 170
# Pattern: metacluster_0pattern_28, Total seqlets: 166
# Pattern: metacluster_0pattern_29, Total seqlets: 121
# Pattern: metacluster_0pattern_30, Total seqlets: 118
# Pattern: metacluster_0pattern_31, Total seqlets: 115
# Pattern: metacluster_0pattern_32, Total seqlets: 66
# Pattern: metacluster_0pattern_33, Total seqlets: 55
# Pattern: metacluster_0pattern_34, Total seqlets: 44
# Pattern: metacluster_0pattern_35, Total seqlets: 39
# Pattern: metacluster_0pattern_36, Total seqlets: 35
# Pattern: metacluster_1pattern_0, Total seqlets: 7669
# Pattern: metacluster_1pattern_1, Total seqlets: 3807
# Pattern: metacluster_1pattern_2, Total seqlets: 2548
# Pattern: metacluster_1pattern_3, Total seqlets: 687
# Pattern: metacluster_1pattern_4, Total seqlets: 489
# Pattern: metacluster_1pattern_5, Total seqlets: 462
# Pattern: metacluster_1pattern_6, Total seqlets: 459
# Pattern: metacluster_1pattern_7, Total seqlets: 434
# Pattern: metacluster_1pattern_8, Total seqlets: 430
# Pattern: metacluster_1pattern_9, Total seqlets: 292
# Pattern: metacluster_1pattern_10, Total seqlets: 238
# Pattern: metacluster_1pattern_11, Total seqlets: 187
# Pattern: metacluster_1pattern_12, Total seqlets: 176
# Pattern: metacluster_1pattern_13, Total seqlets: 167
# Pattern: metacluster_1pattern_14, Total seqlets: 154
# Pattern: metacluster_1pattern_15, Total seqlets: 119
# Pattern: metacluster_1pattern_16, Total seqlets: 95
# Pattern: metacluster_2pattern_0, Total seqlets: 1215
# Pattern: metacluster_2pattern_1, Total seqlets: 1155
# Pattern: metacluster_2pattern_2, Total seqlets: 1115
# Pattern: metacluster_2pattern_3, Total seqlets: 814
# Pattern: metacluster_2pattern_4, Total seqlets: 786
# Pattern: metacluster_2pattern_5, Total seqlets: 684
# Pattern: metacluster_2pattern_6, Total seqlets: 473
# Pattern: metacluster_2pattern_7, Total seqlets: 409
# Pattern: metacluster_2pattern_8, Total seqlets: 325
# Pattern: metacluster_2pattern_9, Total seqlets: 324
# Pattern: metacluster_2pattern_10, Total seqlets: 304
# Pattern: metacluster_2pattern_11, Total seqlets: 297
# Pattern: metacluster_2pattern_12, Total seqlets: 275
# Pattern: metacluster_2pattern_13, Total seqlets: 246
# Pattern: metacluster_2pattern_14, Total seqlets: 221
# Pattern: metacluster_2pattern_15, Total seqlets: 201
# Pattern: metacluster_2pattern_16, Total seqlets: 177
# Pattern: metacluster_2pattern_17, Total seqlets: 172
# Pattern: metacluster_2pattern_18, Total seqlets: 167
# Pattern: metacluster_2pattern_19, Total seqlets: 159
# Pattern: metacluster_2pattern_20, Total seqlets: 111
# Pattern: metacluster_2pattern_21, Total seqlets: 108
# Pattern: metacluster_2pattern_22, Total seqlets: 86
# Pattern: metacluster_2pattern_23, Total seqlets: 64
# Pattern: metacluster_2pattern_24, Total seqlets: 46
# Pattern: metacluster_3pattern_0, Total seqlets: 1868
# Pattern: metacluster_3pattern_1, Total seqlets: 818
# Pattern: metacluster_3pattern_2, Total seqlets: 767
# Pattern: metacluster_3pattern_3, Total seqlets: 664
# Pattern: metacluster_3pattern_4, Total seqlets: 434
# Pattern: metacluster_3pattern_5, Total seqlets: 342
# Pattern: metacluster_3pattern_6, Total seqlets: 309
# Pattern: metacluster_3pattern_7, Total seqlets: 286
# Pattern: metacluster_3pattern_8, Total seqlets: 273
# Pattern: metacluster_3pattern_9, Total seqlets: 229
# Pattern: metacluster_3pattern_10, Total seqlets: 202
# Pattern: metacluster_3pattern_11, Total seqlets: 184
# Pattern: metacluster_3pattern_12, Total seqlets: 149
# Pattern: metacluster_3pattern_13, Total seqlets: 128
# Pattern: metacluster_3pattern_14, Total seqlets: 87
# Pattern: metacluster_3pattern_15, Total seqlets: 80
# Pattern: metacluster_3pattern_16, Total seqlets: 51
# Pattern: metacluster_3pattern_17, Total seqlets: 42
# Pattern: metacluster_3pattern_18, Total seqlets: 30
# Pattern: metacluster_4pattern_0, Total seqlets: 1033
# Pattern: metacluster_4pattern_1, Total seqlets: 679
# Pattern: metacluster_4pattern_2, Total seqlets: 576
# Pattern: metacluster_4pattern_3, Total seqlets: 113
# Pattern: metacluster_5pattern_0, Total seqlets: 1331
# Pattern: metacluster_5pattern_1, Total seqlets: 133
# Pattern: metacluster_5pattern_2, Total seqlets: 102
# Pattern: metacluster_5pattern_3, Total seqlets: 100
# Pattern: metacluster_5pattern_4, Total seqlets: 84
# Pattern: metacluster_5pattern_5, Total seqlets: 68
# Pattern: metacluster_5pattern_6, Total seqlets: 61
# Pattern: metacluster_5pattern_7, Total seqlets: 56

# %%
pattern_seqlets = {}
with open("patterns_seqlets_list_X.txt", "r") as f:
    for line in f:
        parts = line.strip().split(", Total seqlets: ")
        if len(parts) == 2:
            pattern_name = parts[0].split(": ")[1]  # 提取模式名称
            pattern_seqlets[pattern_name] = parts[1]  # 将模式名称与seqlets数量存储在字典中
pattern_seqlets
# Out:
# {'metacluster_0pattern_0': '2426',
#  'metacluster_0pattern_1': '1913',
#  'metacluster_0pattern_2': '1711',
#  'metacluster_0pattern_3': '928',
#  'metacluster_0pattern_4': '642',
#  'metacluster_0pattern_5': '633',
#  'metacluster_0pattern_6': '612',
#  'metacluster_0pattern_7': '602',
#  'metacluster_0pattern_8': '539',
#  'metacluster_0pattern_9': '533',
#  'metacluster_0pattern_10': '532',
#  'metacluster_0pattern_11': '513',
#  'metacluster_0pattern_12': '464',
#  'metacluster_0pattern_13': '450',
#  'metacluster_0pattern_14': '420',
#  'metacluster_0pattern_15': '413',
#  'metacluster_0pattern_16': '413',
#  'metacluster_0pattern_17': '387',
#  'metacluster_0pattern_18': '364',
#  'metacluster_0pattern_19': '357',
#  'metacluster_0pattern_20': '351',
#  'metacluster_0pattern_21': '321',
#  'metacluster_0pattern_22': '315',
#  'metacluster_0pattern_23': '299',
#  'metacluster_0pattern_24': '263',
#  'metacluster_0pattern_25': '251',
#  'metacluster_0pattern_26': '236',
#  'metacluster_0pattern_27': '170',
#  'metacluster_0pattern_28': '166',
#  'metacluster_0pattern_29': '121',
#  'metacluster_0pattern_30': '118',
#  'metacluster_0pattern_31': '115',
#  'metacluster_0pattern_32': '66',
#  'metacluster_0pattern_33': '55',
#  'metacluster_0pattern_34': '44',
#  'metacluster_0pattern_35': '39',
#  'metacluster_0pattern_36': '35',
#  'metacluster_1pattern_0': '7669',
#  'metacluster_1pattern_1': '3807',
#  'metacluster_1pattern_2': '2548',
#  'metacluster_1pattern_3': '687',
#  'metacluster_1pattern_4': '489',
#  'metacluster_1pattern_5': '462',
#  'metacluster_1pattern_6': '459',
#  'metacluster_1pattern_7': '434',
#  'metacluster_1pattern_8': '430',
#  'metacluster_1pattern_9': '292',
#  'metacluster_1pattern_10': '238',
#  'metacluster_1pattern_11': '187',
#  'metacluster_1pattern_12': '176',
#  'metacluster_1pattern_13': '167',
#  'metacluster_1pattern_14': '154',
#  'metacluster_1pattern_15': '119',
#  'metacluster_1pattern_16': '95',
#  'metacluster_2pattern_0': '1215',
#  'metacluster_2pattern_1': '1155',
#  'metacluster_2pattern_2': '1115',
#  'metacluster_2pattern_3': '814',
#  'metacluster_2pattern_4': '786',
#  'metacluster_2pattern_5': '684',
#  'metacluster_2pattern_6': '473',
#  'metacluster_2pattern_7': '409',
#  'metacluster_2pattern_8': '325',
#  'metacluster_2pattern_9': '324',
#  'metacluster_2pattern_10': '304',
#  'metacluster_2pattern_11': '297',
#  'metacluster_2pattern_12': '275',
#  'metacluster_2pattern_13': '246',
#  'metacluster_2pattern_14': '221',
#  'metacluster_2pattern_15': '201',
#  'metacluster_2pattern_16': '177',
#  'metacluster_2pattern_17': '172',
#  'metacluster_2pattern_18': '167',
#  'metacluster_2pattern_19': '159',
#  'metacluster_2pattern_20': '111',
#  'metacluster_2pattern_21': '108',
#  'metacluster_2pattern_22': '86',
#  'metacluster_2pattern_23': '64',
#  'metacluster_2pattern_24': '46',
#  'metacluster_3pattern_0': '1868',
#  'metacluster_3pattern_1': '818',
#  'metacluster_3pattern_2': '767',
#  'metacluster_3pattern_3': '664',
#  'metacluster_3pattern_4': '434',
#  'metacluster_3pattern_5': '342',
#  'metacluster_3pattern_6': '309',
#  'metacluster_3pattern_7': '286',
#  'metacluster_3pattern_8': '273',
#  'metacluster_3pattern_9': '229',
#  'metacluster_3pattern_10': '202',
#  'metacluster_3pattern_11': '184',
#  'metacluster_3pattern_12': '149',
#  'metacluster_3pattern_13': '128',
#  'metacluster_3pattern_14': '87',
#  'metacluster_3pattern_15': '80',
#  'metacluster_3pattern_16': '51',
#  'metacluster_3pattern_17': '42',
#  'metacluster_3pattern_18': '30',
#  'metacluster_4pattern_0': '1033',
#  'metacluster_4pattern_1': '679',
#  'metacluster_4pattern_2': '576',
#  'metacluster_4pattern_3': '113',
#  'metacluster_5pattern_0': '1331',
#  'metacluster_5pattern_1': '133',
#  'metacluster_5pattern_2': '102',
#  'metacluster_5pattern_3': '100',
#  'metacluster_5pattern_4': '84',
#  'metacluster_5pattern_5': '68',
#  'metacluster_5pattern_6': '61',
#  'metacluster_5pattern_7': '56'}

# %%
folder_path = '/rugpfs/fs0/zhao_lab/scratch/xwu05/detect_peaks_scripts/run_model/tfmodisco_seqlogo_X'

for filename in os.listdir(folder_path):
    # 检查是否为PNG文件
    if filename.endswith('.png'):
        # 获取不带扩展名的文件名
        base_name = filename.split('.png')[0]
        # 检查文件名是否在字典中
        if base_name in pattern_seqlets:
            # 构造新文件名
            new_name = f"{base_name}_seqlets_{pattern_seqlets[base_name]}.png"
            # 构造完整的文件路径
            old_file = os.path.join(folder_path, filename)
            new_file = os.path.join(folder_path, new_name)
            # 重命名文件
            os.rename(old_file, new_file)
            print(f"Renamed {filename} to {new_name}")
# Out:
# Renamed metacluster_2pattern_9.png to metacluster_2pattern_9_seqlets_324.png
# Renamed metacluster_2pattern_3.png to metacluster_2pattern_3_seqlets_814.png
# Renamed metacluster_1pattern_10.png to metacluster_1pattern_10_seqlets_238.png
# Renamed metacluster_2pattern_5.png to metacluster_2pattern_5_seqlets_684.png
# Renamed metacluster_1pattern_12.png to metacluster_1pattern_12_seqlets_176.png
# Renamed metacluster_1pattern_2.png to metacluster_1pattern_2_seqlets_2548.png
# Renamed metacluster_3pattern_12.png to metacluster_3pattern_12_seqlets_149.png
# Renamed metacluster_2pattern_6.png to metacluster_2pattern_6_seqlets_473.png
# Renamed metacluster_4pattern_1.png to metacluster_4pattern_1_seqlets_679.png
# Renamed metacluster_3pattern_1.png to metacluster_3pattern_1_seqlets_818.png
# Renamed metacluster_0pattern_32.png to metacluster_0pattern_32_seqlets_66.png
# Renamed metacluster_0pattern_29.png to metacluster_0pattern_29_seqlets_121.png
# Renamed metacluster_1pattern_9.png to metacluster_1pattern_9_seqlets_292.png
# Renamed metacluster_0pattern_30.png to metacluster_0pattern_30_seqlets_118.png
# Renamed metacluster_0pattern_15.png to metacluster_0pattern_15_seqlets_413.png
# Renamed metacluster_2pattern_17.png to metacluster_2pattern_17_seqlets_172.png
# Renamed metacluster_0pattern_11.png to metacluster_0pattern_11_seqlets_513.png
# Renamed metacluster_5pattern_3.png to metacluster_5pattern_3_seqlets_100.png
# Renamed metacluster_1pattern_8.png to metacluster_1pattern_8_seqlets_430.png
# Renamed metacluster_1pattern_13.png to metacluster_1pattern_13_seqlets_167.png
# Renamed metacluster_0pattern_20.png to metacluster_0pattern_20_seqlets_351.png
# Renamed metacluster_2pattern_18.png to metacluster_2pattern_18_seqlets_167.png
# Renamed metacluster_0pattern_9.png to metacluster_0pattern_9_seqlets_533.png
# Renamed metacluster_0pattern_12.png to metacluster_0pattern_12_seqlets_464.png
# Renamed metacluster_0pattern_1.png to metacluster_0pattern_1_seqlets_1913.png
# Renamed metacluster_1pattern_0.png to metacluster_1pattern_0_seqlets_7669.png
# Renamed metacluster_0pattern_19.png to metacluster_0pattern_19_seqlets_357.png
# Renamed metacluster_1pattern_3.png to metacluster_1pattern_3_seqlets_687.png
# Renamed metacluster_1pattern_4.png to metacluster_1pattern_4_seqlets_489.png
# Renamed metacluster_3pattern_0.png to metacluster_3pattern_0_seqlets_1868.png
# Renamed metacluster_1pattern_5.png to metacluster_1pattern_5_seqlets_462.png
# Renamed metacluster_2pattern_14.png to metacluster_2pattern_14_seqlets_221.png
# Renamed metacluster_2pattern_0.png to metacluster_2pattern_0_seqlets_1215.png
# Renamed metacluster_5pattern_0.png to metacluster_5pattern_0_seqlets_1331.png
# Renamed metacluster_0pattern_21.png to metacluster_0pattern_21_seqlets_321.png
# Renamed metacluster_3pattern_11.png to metacluster_3pattern_11_seqlets_184.png
# Renamed metacluster_0pattern_26.png to metacluster_0pattern_26_seqlets_236.png
# Renamed metacluster_0pattern_17.png to metacluster_0pattern_17_seqlets_387.png
# Renamed metacluster_0pattern_4.png to metacluster_0pattern_4_seqlets_642.png
# Renamed metacluster_3pattern_5.png to metacluster_3pattern_5_seqlets_342.png
# Renamed metacluster_3pattern_2.png to metacluster_3pattern_2_seqlets_767.png
# Renamed metacluster_0pattern_28.png to metacluster_0pattern_28_seqlets_166.png
# Renamed metacluster_3pattern_17.png to metacluster_3pattern_17_seqlets_42.png
# Renamed metacluster_2pattern_2.png to metacluster_2pattern_2_seqlets_1115.png
# Renamed metacluster_1pattern_11.png to metacluster_1pattern_11_seqlets_187.png
# Renamed metacluster_0pattern_10.png to metacluster_0pattern_10_seqlets_532.png
# Renamed metacluster_5pattern_7.png to metacluster_5pattern_7_seqlets_56.png
# Renamed metacluster_1pattern_16.png to metacluster_1pattern_16_seqlets_95.png
# Renamed metacluster_0pattern_7.png to metacluster_0pattern_7_seqlets_602.png
# Renamed metacluster_2pattern_4.png to metacluster_2pattern_4_seqlets_786.png
# Renamed metacluster_2pattern_24.png to metacluster_2pattern_24_seqlets_46.png
# Renamed metacluster_5pattern_5.png to metacluster_5pattern_5_seqlets_68.png
# Renamed metacluster_2pattern_13.png to metacluster_2pattern_13_seqlets_246.png
# Renamed metacluster_0pattern_18.png to metacluster_0pattern_18_seqlets_364.png
# Renamed metacluster_2pattern_23.png to metacluster_2pattern_23_seqlets_64.png
# Renamed metacluster_4pattern_0.png to metacluster_4pattern_0_seqlets_1033.png
# Renamed metacluster_0pattern_14.png to metacluster_0pattern_14_seqlets_420.png
# Renamed metacluster_0pattern_36.png to metacluster_0pattern_36_seqlets_35.png
# Renamed metacluster_0pattern_24.png to metacluster_0pattern_24_seqlets_263.png
# Renamed metacluster_0pattern_3.png to metacluster_0pattern_3_seqlets_928.png
# Renamed metacluster_4pattern_2.png to metacluster_4pattern_2_seqlets_576.png
# Renamed metacluster_0pattern_13.png to metacluster_0pattern_13_seqlets_450.png
# Renamed metacluster_1pattern_15.png to metacluster_1pattern_15_seqlets_119.png
# Renamed metacluster_1pattern_14.png to metacluster_1pattern_14_seqlets_154.png
# Renamed metacluster_0pattern_34.png to metacluster_0pattern_34_seqlets_44.png
# Renamed metacluster_2pattern_8.png to metacluster_2pattern_8_seqlets_325.png
# Renamed metacluster_0pattern_0.png to metacluster_0pattern_0_seqlets_2426.png
# Renamed metacluster_2pattern_12.png to metacluster_2pattern_12_seqlets_275.png
# Renamed metacluster_2pattern_16.png to metacluster_2pattern_16_seqlets_177.png
# Renamed metacluster_3pattern_3.png to metacluster_3pattern_3_seqlets_664.png
# Renamed metacluster_3pattern_15.png to metacluster_3pattern_15_seqlets_80.png
# Renamed metacluster_2pattern_7.png to metacluster_2pattern_7_seqlets_409.png
# Renamed metacluster_5pattern_6.png to metacluster_5pattern_6_seqlets_61.png
# Renamed metacluster_3pattern_8.png to metacluster_3pattern_8_seqlets_273.png
# Renamed metacluster_4pattern_3.png to metacluster_4pattern_3_seqlets_113.png
# Renamed metacluster_2pattern_19.png to metacluster_2pattern_19_seqlets_159.png
# Renamed metacluster_5pattern_1.png to metacluster_5pattern_1_seqlets_133.png
# Renamed metacluster_1pattern_7.png to metacluster_1pattern_7_seqlets_434.png
# Renamed metacluster_0pattern_31.png to metacluster_0pattern_31_seqlets_115.png
# Renamed metacluster_5pattern_4.png to metacluster_5pattern_4_seqlets_84.png
# Renamed metacluster_0pattern_22.png to metacluster_0pattern_22_seqlets_315.png
# Renamed metacluster_3pattern_9.png to metacluster_3pattern_9_seqlets_229.png
# Renamed metacluster_2pattern_15.png to metacluster_2pattern_15_seqlets_201.png
# Renamed metacluster_2pattern_1.png to metacluster_2pattern_1_seqlets_1155.png
# Renamed metacluster_0pattern_23.png to metacluster_0pattern_23_seqlets_299.png
# Renamed metacluster_0pattern_27.png to metacluster_0pattern_27_seqlets_170.png
# Renamed metacluster_3pattern_7.png to metacluster_3pattern_7_seqlets_286.png
# Renamed metacluster_0pattern_6.png to metacluster_0pattern_6_seqlets_612.png
# Renamed metacluster_3pattern_14.png to metacluster_3pattern_14_seqlets_87.png
# Renamed metacluster_0pattern_33.png to metacluster_0pattern_33_seqlets_55.png
# Renamed metacluster_3pattern_4.png to metacluster_3pattern_4_seqlets_434.png
# Renamed metacluster_3pattern_6.png to metacluster_3pattern_6_seqlets_309.png
# Renamed metacluster_1pattern_6.png to metacluster_1pattern_6_seqlets_459.png
# Renamed metacluster_3pattern_10.png to metacluster_3pattern_10_seqlets_202.png
# Renamed metacluster_0pattern_25.png to metacluster_0pattern_25_seqlets_251.png
# Renamed metacluster_0pattern_5.png to metacluster_0pattern_5_seqlets_633.png
# Renamed metacluster_2pattern_11.png to metacluster_2pattern_11_seqlets_297.png
# Renamed metacluster_3pattern_16.png to metacluster_3pattern_16_seqlets_51.png
# Renamed metacluster_2pattern_22.png to metacluster_2pattern_22_seqlets_86.png
# Renamed metacluster_3pattern_13.png to metacluster_3pattern_13_seqlets_128.png
# Renamed metacluster_5pattern_2.png to metacluster_5pattern_2_seqlets_102.png
# Renamed metacluster_3pattern_18.png to metacluster_3pattern_18_seqlets_30.png
# Renamed metacluster_0pattern_35.png to metacluster_0pattern_35_seqlets_39.png
# Renamed metacluster_0pattern_2.png to metacluster_0pattern_2_seqlets_1711.png
# Renamed metacluster_2pattern_10.png to metacluster_2pattern_10_seqlets_304.png
# Renamed metacluster_2pattern_21.png to metacluster_2pattern_21_seqlets_108.png
# Renamed metacluster_0pattern_16.png to metacluster_0pattern_16_seqlets_413.png
# Renamed metacluster_1pattern_1.png to metacluster_1pattern_1_seqlets_3807.png
# Renamed metacluster_2pattern_20.png to metacluster_2pattern_20_seqlets_111.png
# Renamed metacluster_0pattern_8.png to metacluster_0pattern_8_seqlets_539.png
